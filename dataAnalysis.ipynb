# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Read in the data

# df = pd.read_csv('./data/safe/combined.csv')
df = pd.read_csv('./data/safe/2019-school-stats.csv')

# %%
df.sample(5)

df.describe()

# Get the number of rows and columns
df.shape

# Get the column names
df.columns

sns.displot(df['G'], kde=True)

mapa = {'Champions': 8, '2ND' : 7, 'F4' : 6, 'E8' : 5, 'S16' : 4, 'R32' : 3, 'R64' : 2, 'R68' : 1}
df['POSTSEASON_value'] = df['POSTSEASON'].map(mapa)

df['POSTSEASON_value'].value_counts()
# Out:
# 2.0    32
# 3.0    16
# 4.0     8
# 5.0     4
# 1.0     4
# 6.0     2
# 7.0     1
# 8.0     1
# Name: POSTSEASON_value, dtype: int64

# %%
plt.figure(figsize=(27, 27))
drop = ['School','Overall.W', 'Overall.L', 'Conf.W', 'Conf.L', 'Home.W', 'Home.L', 'Away.W', 'Away.L', 'TP', 'OP', 'MP', 'POSTSEASON', 'REGION']
df.drop(drop, axis=1, inplace=True)
p = sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', square=True)

# %%
corr_mat = df.corr()
corr_mat['POSTSEASON_value'].sort_values(ascending=False)
# Out:
# POSTSEASON_value    1.000000
# G                   0.751932
# SRS                 0.701716
# SOS                 0.519210
# FGA                 0.513551
# W-L%                0.501524
# 3PA                 0.408359
# ORB                 0.316911
# STL                 0.302759
# PF                  0.272060
# TRB                 0.237763
# 3P                  0.201620
# TOV                 0.172474
# 3PAr                0.153276
# FG                  0.115447
# BLK                 0.086845
# STL%                0.073758
# FTA                 0.033625
# FT                 -0.011491
# TOV%               -0.042259
# ORB%               -0.045563
# AST                -0.053318
# BLK%               -0.086332
# AST%               -0.159324
# FT%                -0.188213
# Pace               -0.197761
# FTr                -0.207080
# FT/FGA             -0.235111
# TRB%               -0.314738
# 3P%                -0.322931
# ORtg               -0.424507
# eFG%               -0.455587
# ...
